# %% [markdown]
# # In this notebook I am going to load data about tires from the emex.ru

# %% [markdown]
# ### First of all, we need to add simple libraries for working with dataframes, like writing or reading csv files

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ### Then we need to install libraries for web scraping
# - Selenium: for requesting and getting string from the ulr with the JavaScript
# - BeautifulSoup: used to seperate all items and tags from the given string
# - WebDriver-manager: used to work with Chrome(in this case) browser

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.7/site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in /opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.7/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.7/site-packages (from selenium) (1.25.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in /opt/anaconda3/lib/python3.7/site-packages (3.2.1)
# Requirement already satisfied: configparser in /opt/anaconda3/lib/python3.7/site-packages (from webdriver-manager) (5.0.0)
# Requirement already satisfied: crayons in /opt/anaconda3/lib/python3.7/site-packages (from webdriver-manager) (0.3.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (from webdriver-manager) (2.22.0)
# Requirement already satisfied: colorama in /opt/anaconda3/lib/python3.7/site-packages (from crayons->webdriver-manager) (0.4.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests->webdriver-manager) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests->webdriver-manager) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests->webdriver-manager) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests->webdriver-manager) (2.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import re
import time

# %% [markdown]
# ### Now we are ready to work with web page
# 1) We need to select url
# <br>2) Request to that url
# <br>3) Clicking the button 'eще' five times (in this case five is enough)
# <br>4) Get html code as string from the url
# <br>5) Seperate all tags by using BeatifulSoup

# %%
url = 'https://emex.ru/Accessories/Accessories?CAT_ID=17&s%5B0%5D.i=Price&s%5B0%5D.d=0&s%5B1%5D.i=Rating&s%5B1%5D.d=2'

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
# Out:
# [WDM] - Current google-chrome version is 83.0.4103
# [WDM] - Get LATEST driver version for 83.0.4103
# [WDM] - Driver [/Users/sabina/.wdm/drivers/chromedriver/mac64/83.0.4103.39/chromedriver] found in cache

# %%
for i in range(5):
    try:
        loadMoreButton = driver.find_element_by_xpath("//div[contains(text(), 'Ещё')]")
        time.sleep(2)
        loadMoreButton.click()
        time.sleep(5)

    except Exception as e:
        print (e)

# %%
page = driver.page_source
page_soup = BeautifulSoup(page,'html.parser')

# %%
title = page_soup.title
title
# Out:
# <title>Шины для легковых автомобилей от ведущих производителей: Michelin, Pirelli, Dunlop, Good year</title>

# %% [markdown]
# ### Now we need to get following info about tires:
# 1) Title
# <br>2) Link to image
# <br>3) Width
# <br>4) Height
# <br>5) Diameter
# <br>6) Cost
# And we need to save all of this info in dictionary

# %%
content = page_soup.find_all('div', 'item')
rows = []
for item in content:
    imges = item.find_all('img')
    link = []
    for i in imges:
        link.append(i['src'])
        
    title = item.find('span', 'name').get_text()
    info = item.find_all('div', 'desc')
    radius = ''
    for i in info:
        Width = i.find_all('span')[0].get_text()
        Height = i.find_all('span')[2].get_text()
        Diameter = i.find_all('span')[5].get_text()
    cost = item.find('a', 'styledbutton').get_text().replace('\xa0', '').replace('\n            ','').replace('\n', '')
    row = {
        'title': title,
        'link': link,
        'Width': Width,
        'Height': Height,
        'Diameter':Diameter,
        'Cost': cost
    }
    rows.append(row)
    
rows
# Out:
# [{'title': 'R15 185/60 Cordiant SPORT-2 PS-501 (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164250&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 2583 ₽'},
#  {'title': '195/65R15 91T AE01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092633&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4431 ₽'},
#  {'title': 'Michelin 91V Energy Saver',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093385&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 4307 ₽'},
#  {'title': 'R13 175/70 Amtel Planet DC В-105 (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098448&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 2808 ₽'},
#  {'title': '185/60R14 82T AE01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092614&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 3507 ₽'},
#  {'title': 'Nokian',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119453&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3345 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119229&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4994 ₽'},
#  {'title': '205/55R16 91H AE01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092619&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 4077 ₽'},
#  {'title': 'Шина Nokian Nordman 5 185/65R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044700&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3173 ₽'},
#  {'title': '195/65 R 15 95T Nordman 4 XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5120230&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3225 ₽'},
#  {'title': 'Ice Cruiser 7000',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092125&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3775 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119888&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4271 ₽'},
#  {'title': 'Шина Nokian Nordman 5 185/65R14',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044699&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3143 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086091&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 5501 ₽'},
#  {'title': 'Шина Nokian Nordman 5 205/55R16',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044708&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 4483 ₽'},
#  {'title': '195/60 R15 88H ENERGY XM2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6043746&h=150'],
#   'Width': '195',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 3912 ₽'},
#  {'title': 'R17 225/65 Hankook Dynapro HP RA23 102H (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094415&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 6770 ₽'},
#  {'title': 'Шина Nokian Nordman 5 175/70R14',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044713&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 2960 ₽'},
#  {'title': 'Yokohama IG30',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046411&h=150'],
#   'Width': '215',
#   'Height': '65',
#   'Diameter': '16',
#   'Cost': 'Цены от 6030 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092460&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 3507 ₽'},
#  {'title': 'Шина Yokohama Iceguard Studless IG30',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046404&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 5781 ₽'},
#  {'title': '235/55 ZR 17 103Y NOKIAN HAKKA BLACK XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092932&h=150'],
#   'Width': '235',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 11608 ₽'},
#  {'title': 'Yokohama AA01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092459&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4547 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta 8 205/55R16',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044678&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 6304 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092456&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3704 ₽'},
#  {'title': '265/65R17 112 H ECOPIA EP850',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6039576&h=150'],
#   'Width': '265',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 12958 ₽'},
#  {'title': 'Sava',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117124&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3015 ₽'},
#  {'title': '155/70R13 CORDIANT ROAD_RUNNER 75T (457442784)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164274&h=150'],
#   'Width': '155',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 2376 ₽'},
#  {'title': '225/60R17 Dunlop GRANDTREK ST20 99H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094869&h=150'],
#   'Width': '225',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 9828 ₽'},
#  {'title': '225/65R17 Dunlop GRANDTREK AT3 102H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095071&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 6750 ₽'},
#  {'title': 'Шина Nokian Nordman 5 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044763&h=150'],
#   'Width': '225',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 12178 ₽'},
#  {'title': '195/65R15 91 H ECOPIA EP150',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098060&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4518 ₽'},
#  {'title': '225/65R17 102 H ECOPIA EP850',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5097929&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 7598 ₽'},
#  {'title': 'Шина Yokohama BluEarth AE-01 205/65R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046539&h=150'],
#   'Width': '205',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4619 ₽'},
#  {'title': 'Sava',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117114&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 4925 ₽'},
#  {'title': '195/60R15 88H AE01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092626&h=150'],
#   'Width': '195',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 26145 ₽'},
#  {'title': 'Шина Yokohama BluEarth AE-01 215/60R16',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046578&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 7219 ₽'},
#  {'title': 'Michelin 82T Energy XM2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168556&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3842 ₽'},
#  {'title': '195/65R15 Dunlop SP SPORT LM704 91V',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164573&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3484 ₽'},
#  {'title': 'Tigar',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10171140&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 3107 ₽'},
#  {'title': 'Шина Bridgestone ICE CRUISER 7000',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086075&h=150'],
#   'Width': '205',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 5254 ₽'},
#  {'title': '205/70R15 96H G051',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092568&h=150'],
#   'Width': '205',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 6568 ₽'},
#  {'title': '195/70 R15C 104/102R CARGO SPEED',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10171165&h=150'],
#   'Width': '195',
#   'Height': '70',
#   'Diameter': '15C',
#   'Cost': 'Цены от 4558 ₽'},
#  {'title': 'Nokian',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5120212&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 2821 ₽'},
#  {'title': '225/70R15 Dunlop GRANDTREK AT3 100T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095077&h=150'],
#   'Width': '225',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 7373 ₽'},
#  {'title': 'Шина Continental CONTIPREMIUMCONTACT 5 195/65R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6040708&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 6777 ₽'},
#  {'title': '225/50R17 98Y TL XL FR ContiSportContact 5',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5097807&h=150'],
#   'Width': '225',
#   'Height': '50',
#   'Diameter': '17',
#   'Cost': 'Цены от 10849 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5118075&h=150'],
#   'Width': '225',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 10383 ₽'},
#  {'title': 'Kumho',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117922&h=150'],
#   'Width': '195',
#   'Height': '75',
#   'Diameter': '16',
#   'Cost': 'Цены от 6494 ₽'},
#  {'title': 'Cordiant',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164271&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4267 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119209&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 8309 ₽'},
#  {'title': 'Шина Tigar Winter-1 175/65R14 82T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6045585&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 2741 ₽'},
#  {'title': 'R16 205/60 Cordiant Winter Drive PW-1 91T (зима)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5118534&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 4919 ₽'},
#  {'title': 'Шина Pirelli Winter ICE ZERO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10170336&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 8589 ₽'},
#  {'title': 'Шина Cordiant ROAD RUNNER PS-1',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041084&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 2792 ₽'},
#  {'title': '205/70R15 Dunlop SP TOURING T1 96T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164566&h=150'],
#   'Width': '205',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 4575 ₽'},
#  {'title': '175/65R14 Dunlop SP TOURING T1 82T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164565&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 2680 ₽'},
#  {'title': '175/65R14 82T TL Brillantis 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098238&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3539 ₽'},
#  {'title': '185/65R14 Dunlop SP TOURING T1 86T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041652&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3093 ₽'},
#  {'title': 'R16 215/65 Hankook Dynapro HP RA23 98H (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094561&h=150'],
#   'Width': '215',
#   'Height': '65',
#   'Diameter': '16',
#   'Cost': 'Цены от 5946 ₽'},
#  {'title': 'Шина Bridgestone DMV-2 265/65R17 112R',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086023&h=150'],
#   'Width': '265',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 14298 ₽'},
#  {'title': 'Ice Cruiser 7000',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6039737&h=150'],
#   'Width': '215',
#   'Height': '65',
#   'Diameter': '16',
#   'Cost': 'Цены от 6497 ₽'},
#  {'title': 'Michelin 82T Energy Saver+',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168511&h=150'],
#   'Width': '195',
#   'Height': '50',
#   'Diameter': '15',
#   'Cost': 'Цены от 4636 ₽'},
#  {'title': 'Шина Tigar Sigura STUD 195/65R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6045587&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3908 ₽'},
#  {'title': 'Yokohama AA01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092450&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3510 ₽'},
#  {'title': 'R14 185/60 Cordiant Winter Drive PW-1 82T (зима)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164260&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 2649 ₽'},
#  {'title': '205/55 R 16 94T Nordman 4 XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5120233&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 3579 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086102&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 8181 ₽'},
#  {'title': '205/55R16 91H TL ContiEcoContact 5 MO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5097154&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 5069 ₽'},
#  {'title': 'R17 275/55 Toyo Proxes ST 109V (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092774&h=150'],
#   'Width': '275',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 9632 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta 8 185/65R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044668&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4369 ₽'},
#  {'title': 'Шина Yokohama Geolandar I/T-S G073',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046425&h=150'],
#   'Width': '255',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 9669 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086089&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 5565 ₽'},
#  {'title': '225/65R17 102H TL FR MP85 Hectorra 4X4',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10167522&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 5825 ₽'},
#  {'title': '265/70 R 16 112T NOKIAN ROTIIVA AT',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169398&h=150'],
#   'Width': '265',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 7454 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119979&h=150'],
#   'Width': '275',
#   'Height': '60',
#   'Diameter': '20',
#   'Cost': 'Цены от 17350 ₽'},
#  {'title': '265/65 R 17 116T Nokian Rotiiva AT XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169399&h=150'],
#   'Width': '265',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 9891 ₽'},
#  {'title': 'Шина Nokian Nordman 5 185/70R14',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044697&h=150'],
#   'Width': '185',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 3282 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5118103&h=150'],
#   'Width': '155',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 3840 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166946&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3218 ₽'},
#  {'title': 'Blizzak VRX',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6085967&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 5001 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta 8 215/55R16',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044680&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 7499 ₽'},
#  {'title': 'Yokohama G073',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046420&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 7594 ₽'},
#  {'title': 'Michelin',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117548&h=150'],
#   'Width': '225',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 10538 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5118061&h=150'],
#   'Width': '265',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 10067 ₽'},
#  {'title': '195/50ZR15 Dunlop SP SPORT MAXX 82W',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095116&h=150'],
#   'Width': '195',
#   'Height': '50',
#   'Diameter': '15',
#   'Cost': 'Цены от 3989 ₽'},
#  {'title': 'Michelin 106Y XL Latitude sport 3',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6043793&h=150'],
#   'Width': '275',
#   'Height': '40',
#   'Diameter': '20',
#   'Cost': 'Цены от 17463 ₽'},
#  {'title': '185/75R16C 104/102R TL MPS330 Maxilla 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094068&h=150'],
#   'Width': '185',
#   'Height': '75',
#   'Diameter': '16',
#   'Cost': 'Цены от 6139 ₽'},
#  {'title': 'Шина Bridgestone BLIZZAK VRX 185/65R14',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6085983&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 6023 ₽'},
#  {'title': 'LT31x10,5/ R 15 109S Nokian Rotiiva AT',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169401&h=150'],
#   'Width': '31',
#   'Height': '10,5',
#   'Diameter': '15',
#   'Cost': 'Цены от 7365 ₽'},
#  {'title': 'R15 195/60 Hankook K424 Optimo ME02 88H (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166922&h=150'],
#   'Width': '195',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 3966 ₽'},
#  {'title': 'Good year 185/65R15 88T UltraGrip Ice Arctic D-STUD',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10165087&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4179 ₽'},
#  {'title': 'Шина зимняя, оборудована под шип, шипов нет Tigar Cargo Speed Winter',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10171139&h=150'],
#   'Width': '225',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 6596 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086104&h=150'],
#   'Width': '215',
#   'Height': '65',
#   'Diameter': '16',
#   'Cost': 'Цены от 7373 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119893&h=150'],
#   'Width': '145',
#   'Height': '70',
#   'Diameter': '12',
#   'Cost': 'Цены от 4099 ₽'},
#  {'title': 'Шина Bridgestone DMV-2 235/55R18 100T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086014&h=150'],
#   'Width': '235',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 14561 ₽'},
#  {'title': '245/60 R 18 109T Nokian HKPL 7 SUV XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119377&h=150'],
#   'Width': '245',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 12634 ₽'},
#  {'title': 'Bridgestone',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092299&h=150'],
#   'Width': '275',
#   'Height': '55',
#   'Diameter': '20',
#   'Cost': 'Цены от 20379 ₽'},
#  {'title': 'Nokian',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169547&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 2719 ₽'},
#  {'title': '205/60R16 Dunlop SP TOURING T1 92H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164549&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 4400 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094488&h=150'],
#   'Width': '225',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 9949 ₽'},
#  {'title': '215/60R16 99H XL P7cint',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10170247&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 6498 ₽'},
#  {'title': 'Шина Tigar Winter-1 175/70R13 82T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6045583&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 2485 ₽'},
#  {'title': 'Шина зимняя, оборудована под шип, шипов нет Tigar Cargo Speed Winter',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10171160&h=150'],
#   'Width': '195',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 5663 ₽'},
#  {'title': '225/50R17 98Y XL P7Blue',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092851&h=150'],
#   'Width': '225',
#   'Height': '50',
#   'Diameter': '17',
#   'Cost': 'Цены от 10698 ₽'},
#  {'title': 'Шина Tigar Cargo Speed Winter',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6090431&h=150'],
#   'Width': '195',
#   'Height': '75',
#   'Diameter': '16C',
#   'Cost': 'Цены от 6027 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166900&h=150'],
#   'Width': '285',
#   'Height': '50',
#   'Diameter': '20',
#   'Cost': 'Цены от 14863 ₽'},
#  {'title': 'Шина Bridgestone BLIZZAK SPIKE-01 195/65R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6085917&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 5136 ₽'},
#  {'title': '165/65 R 14 79T Nordman 4',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117420&h=150'],
#   'Width': '165',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3816 ₽'},
#  {'title': 'Michelin 91H Energy XM2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168535&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 5095 ₽'},
#  {'title': 'Hankook',
#   'link': ['/Areas/Accessories/Content/Images/catalog-no-photo.png'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 5641 ₽'},
#  {'title': '225/45ZR17 Dunlop SP SPORT LM704 94W',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095032&h=150'],
#   'Width': '225',
#   'Height': '45',
#   'Diameter': '17',
#   'Cost': 'Цены от 6047 ₽'},
#  {'title': 'Michelin 225/65 R17 106H XL Latitude Alpin 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6043796&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 14187 ₽'},
#  {'title': 'R16 215/60 Cordiant Sport-2 PS-501 99V (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041080&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 4975 ₽'},
#  {'title': 'R16 205/55 Cordiant Polar-2 PW-502 91T (шип)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5118536&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 4284 ₽'},
#  {'title': 'Шина Yokohama Iceguard Studless IG50',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046564&h=150'],
#   'Width': '195',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 5349 ₽'},
#  {'title': '185/65 R15 88T ENERGY XM2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6043806&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3814 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5118106&h=150'],
#   'Width': '215',
#   'Height': '50',
#   'Diameter': '17',
#   'Cost': 'Цены от 7085 ₽'},
#  {'title': '225/55 R 17 101R Nokian HKPL R2 XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169407&h=150'],
#   'Width': '225',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 9617 ₽'},
#  {'title': '215/70 R 16 100T NOKIAN ROTIIVA AT',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092994&h=150'],
#   'Width': '215',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 6362 ₽'},
#  {'title': '205/55ZR16 Dunlop SP SPORT MAXX 91W',
#   'link': ['/Areas/Accessories/Content/Images/catalog-no-photo.png'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 4425 ₽'},
#  {'title': 'Шина Hankook Ventus ST RH06',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6042417&h=150'],
#   'Width': '265',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 10997 ₽'},
#  {'title': 'R14 185/60 Cordiant Sport-2 82H (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095396&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 2502 ₽'},
#  {'title': 'Kumho',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10167237&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3485 ₽'},
#  {'title': 'Шина Kumho WinterCraft Ice WI31',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6042776&h=150'],
#   'Width': '195',
#   'Height': '55',
#   'Diameter': '15',
#   'Cost': 'Цены от 4519 ₽'},
#  {'title': 'Michelin 265/65 R17 112T Latitude X-Ice 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117639&h=150'],
#   'Width': '265',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 12046 ₽'},
#  {'title': '205/65R15 94 H ECOPIA EP150',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098082&h=150'],
#   'Width': '205',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4650 ₽'},
#  {'title': 'Tigar',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10171129&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 2888 ₽'},
#  {'title': 'Sava',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117120&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3301 ₽'},
#  {'title': 'Шина Tigar Sigura STUD 175/70R13',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6045580&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 2744 ₽'},
#  {'title': 'Шина зимняя, оборудована под шип, шипов нет KUMHO WinterCraft ice Wi31',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10167235&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 4858 ₽'},
#  {'title': 'Blizzak VRX',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6085958&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 5836 ₽'},
#  {'title': 'Kumho',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117958&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3857 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094493&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 3570 ₽'},
#  {'title': 'Dunlop GRANDTREK SJ6 116Q',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041559&h=150'],
#   'Width': '285',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 7735 ₽'},
#  {'title': '215/60R17 96H TL ContiEcoContact 5',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164020&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 9877 ₽'},
#  {'title': 'Шина Bridgestone ICE CRUISER 7000',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6039735&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 7735 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086092&h=150'],
#   'Width': '205',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 6955 ₽'},
#  {'title': 'Yokohama AA01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092436&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 3978 ₽'},
#  {'title': '215/55R18 99V TL XL FR ContiPremiumContact 2 E',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10163933&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 11741 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166924&h=150'],
#   'Width': '185',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 4144 ₽'},
#  {'title': 'LT235/85 R 16 120/116R NOKIAN ROTIIVA AT',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169402&h=150'],
#   'Width': '235',
#   'Height': '85',
#   'Diameter': '16',
#   'Cost': 'Цены от 8071 ₽'},
#  {'title': '155/65 R 14 75T Nokian HKPL 8',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119734&h=150'],
#   'Width': '155',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 4569 ₽'},
#  {'title': 'Good year 195/55R16 87T UltraGrip Ice Arctic D-STUD',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6042097&h=150'],
#   'Width': '195',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 6609 ₽'},
#  {'title': 'Michelin 97V XL Primacy 3',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093622&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 10064 ₽'},
#  {'title': 'Шина Yokohama Iceguard Studless IG50',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046573&h=150'],
#   'Width': '225',
#   'Height': '40',
#   'Diameter': '18',
#   'Cost': 'Цены от 11671 ₽'},
#  {'title': 'Шина летняя Classe Premiere CP661 175/70R13 82T',
#   'link': ['/Areas/Accessories/Content/Images/catalog-no-photo.png'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 6051 ₽'},
#  {'title': 'Шина Tigar Winter-1 185/65R14 86T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10171159&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3108 ₽'},
#  {'title': '185/60R14 Dunlop SP SPORT LM704 82H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095016&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 2631 ₽'},
#  {'title': '195/65R15 Dunlop SP TOURING T1 91T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164556&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3283 ₽'},
#  {'title': '185/60R14 Dunlop SP TOURING T1 82T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164548&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 2776 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119911&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 7213 ₽'},
#  {'title': 'Шина Nokian Nordman 5 185/55R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044706&h=150'],
#   'Width': '185',
#   'Height': '55',
#   'Diameter': '15',
#   'Cost': 'Цены от 4017 ₽'},
#  {'title': '225/60R18 Dunlop GRANDTREK ST30 100H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164538&h=150'],
#   'Width': '225',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 8702 ₽'},
#  {'title': '225/65R17 Dunlop GRANDTREK ST30 102H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094859&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 6835 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166952&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 9197 ₽'},
#  {'title': 'Michelin 98W XL Primacy 3',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168388&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 8748 ₽'},
#  {'title': 'Matador',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5062042&h=150'],
#   'Width': '205',
#   'Height': '65',
#   'Diameter': '16',
#   'Cost': 'Цены от 7046 ₽'},
#  {'title': 'Michelin 82T Energy XM2 DT1',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168524&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 3772 ₽'},
#  {'title': '205/60R16 92H P7cint',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10170238&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 5799 ₽'},
#  {'title': '145/65R15 Dunlop SP SPORT 2030 72S',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164542&h=150'],
#   'Width': '145',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3863 ₽'},
#  {'title': '255/50R19 107W V802',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092487&h=150'],
#   'Width': '255',
#   'Height': '50',
#   'Diameter': '19',
#   'Cost': 'Цены от 16226 ₽'},
#  {'title': 'Шина зимняя Kumho Power Grip',
#   'link': ['/Areas/Accessories/Content/Images/catalog-no-photo.png'],
#   'Width': '195',
#   'Height': '75',
#   'Diameter': '16C',
#   'Cost': 'Цены от 7990 ₽'},
#  {'title': 'Kumho',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10167239&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3024 ₽'},
#  {'title': '175/65 R 14 86T Nokian HKPL 8 XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169538&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 4194 ₽'},
#  {'title': 'Yokohama IG30',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046405&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 6026 ₽'},
#  {'title': 'R15 195/65 Amtel Planet DC B-108 (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098457&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3657 ₽'},
#  {'title': 'Nokian',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169554&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 3301 ₽'},
#  {'title': 'Шина Yokohama A.Drive AA01 195/60R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046651&h=150'],
#   'Width': '195',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 4811 ₽'},
#  {'title': 'Шина Michelin X-ICE-3 205/55R16 94H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6043700&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 6844 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166929&h=150'],
#   'Width': '215',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 7028 ₽'},
#  {'title': 'Ice Cruiser 7000',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086085&h=150'],
#   'Width': '235',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 11444 ₽'},
#  {'title': '245/45 R19 102Y XL PILOT SPORT 3 MO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168320&h=150'],
#   'Width': '245',
#   'Height': '45',
#   'Diameter': '19',
#   'Cost': 'Цены от 16597 ₽'},
#  {'title': '235/55ZR17 103Y V103',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092535&h=150'],
#   'Width': '235',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 9612 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086101&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 6717 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166935&h=150'],
#   'Width': '235',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 9319 ₽'},
#  {'title': '225/45ZR17 Dunlop SP SPORT MAXX 94Y',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095124&h=150'],
#   'Width': '225',
#   'Height': '45',
#   'Diameter': '17',
#   'Cost': 'Цены от 7742 ₽'},
#  {'title': 'R14 185/60 Sava Eskimo S3+ 82T (зима)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117132&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 3186 ₽'},
#  {'title': 'Michelin 86H Energy XM2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168499&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 4022 ₽'},
#  {'title': 'R16C 215/75 Tigar Cargo Speed 113/111R (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10171142&h=150'],
#   'Width': '215',
#   'Height': '75',
#   'Diameter': '16',
#   'Cost': 'Цены от 5958 ₽'},
#  {'title': 'R17 235/55 Hankook Dynapro HP RA23 99V (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166908&h=150'],
#   'Width': '235',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 10406 ₽'},
#  {'title': 'Bridgestone',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098028&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4933 ₽'},
#  {'title': 'Шина Cordiant SPORT 2 PS-501',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041159&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 2789 ₽'},
#  {'title': '205/70R15 CORDIANT ALL_TERRAIN 100H (293517616)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164251&h=150'],
#   'Width': '205',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 4342 ₽'},
#  {'title': 'R15 195/65 Cordiant Winter Drive PW-1 91T (зима)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164261&h=150'],
#   'Width': '195',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 2962 ₽'},
#  {'title': 'Yokohama G051',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092582&h=150'],
#   'Width': '245',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 7920 ₽'},
#  {'title': '175/65 R 15 88T Nokian HKPL 8 XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169540&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 5365 ₽'},
#  {'title': 'Bridgestone',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098030&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 5267 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166932&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 7180 ₽'},
#  {'title': 'Bridgestone',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098016&h=150'],
#   'Width': '195',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 6370 ₽'},
#  {'title': 'Шина Barum Brillantis 2 175/70R13',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6039073&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '13',
#   'Cost': 'Цены от 3604 ₽'},
#  {'title': '215/60 R 16 99H Nokian Hakka Green XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093071&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 9308 ₽'},
#  {'title': 'Шина Nokian Nordman 5 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044759&h=150'],
#   'Width': '225',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 14566 ₽'},
#  {'title': '205/55 R 16 94R Nordman RS XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117528&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 5292 ₽'},
#  {'title': 'Yokohama AA01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092466&h=150'],
#   'Width': '205',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4265 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119247&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '14',
#   'Cost': 'Цены от 5426 ₽'},
#  {'title': 'Kumho',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10167220&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 4996 ₽'},
#  {'title': '185/60R15 Dunlop SP TOURING T1 84H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095055&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 3269 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5120152&h=150'],
#   'Width': '265',
#   'Height': '70',
#   'Diameter': '17',
#   'Cost': 'Цены от 8961 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119243&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 5134 ₽'},
#  {'title': 'Ice Cruiser 7000',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086066&h=150'],
#   'Width': '245',
#   'Height': '50',
#   'Diameter': '20',
#   'Cost': 'Цены от 15470 ₽'},
#  {'title': 'Michelin 265/65R17 116T XL Latitude X-Ice North 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117748&h=150'],
#   'Width': '265',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 13051 ₽'},
#  {'title': 'Bridgestone',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086013&h=150'],
#   'Width': '225',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 11064 ₽'},
#  {'title': 'Шина Yokohama Iceguard Studless IG50',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046562&h=150'],
#   'Width': '215',
#   'Height': '65',
#   'Diameter': '16',
#   'Cost': 'Цены от 7650 ₽'},
#  {'title': '215/65R16 98H TL FR MP82 CONQUERRA 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093789&h=150'],
#   'Width': '215',
#   'Height': '65',
#   'Diameter': '16',
#   'Cost': 'Цены от 5026 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086099&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 11007 ₽'},
#  {'title': 'Michelin 255/55 R18 109T XL Latitude X-Ice 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117635&h=150'],
#   'Width': '255',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 17455 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086069&h=150'],
#   'Width': '175',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 4765 ₽'},
#  {'title': 'Blizzak Spike-01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6085948&h=150'],
#   'Width': '235',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 9695 ₽'},
#  {'title': '235/45 ZR 17 97Y NOKIAN HAKKA BLACK XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092924&h=150'],
#   'Width': '235',
#   'Height': '45',
#   'Diameter': '17',
#   'Cost': 'Цены от 8318 ₽'},
#  {'title': 'Шина Matador MP 44 Elite',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6043213&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 6806 ₽'},
#  {'title': 'Шина Dunlop Winter MAXX 1',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041650&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 3280 ₽'},
#  {'title': 'Bridgestone',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086017&h=150'],
#   'Width': '265',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 15605 ₽'},
#  {'title': '215/55 R16 93V ENERGY SAVER',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168337&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 7062 ₽'},
#  {'title': '185/70R14 Dunlop SP TOURING T1 88T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164560&h=150'],
#   'Width': '185',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 3468 ₽'},
#  {'title': 'Шина Bridgestone DMV-2 285/60R18 116R',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6039695&h=150'],
#   'Width': '285',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 15511 ₽'},
#  {'title': '205/65R15 Dunlop SP TOURING T1 94T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164558&h=150'],
#   'Width': '205',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 4340 ₽'},
#  {'title': 'Шина Yokohama Geolandar I/T-S G073',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046505&h=150'],
#   'Width': '225',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 7770 ₽'},
#  {'title': 'Michelin 215/70 R15C 109/107R Agilis X-Ice North',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168532&h=150'],
#   'Width': '215',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 9687 ₽'},
#  {'title': 'Ice Cruiser 7000',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086083&h=150'],
#   'Width': '275',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 11417 ₽'},
#  {'title': 'Шина Bridgestone DMV-2 235/65R17 108S',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086022&h=150'],
#   'Width': '235',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 12935 ₽'},
#  {'title': 'Шина Bridgestone DMV-2 285/65R17 116R',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086025&h=150'],
#   'Width': '285',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 14475 ₽'},
#  {'title': '225/60 R 17 99T Nokian HKPL 7 SUV Flat Run',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119380&h=150'],
#   'Width': '225',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 17245 ₽'},
#  {'title': '235/45R17 94W TL FR ContiSportContact 5 ContiSeal',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6040542&h=150'],
#   'Width': '235',
#   'Height': '45',
#   'Diameter': '17',
#   'Cost': 'Цены от 10469 ₽'},
#  {'title': 'Michelin 111W Latitude sport MO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168497&h=150'],
#   'Width': '275',
#   'Height': '55',
#   'Diameter': '19',
#   'Cost': 'Цены от 16248 ₽'},
#  {'title': '185/65 R 14 90T Nokian HKPL 8 XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169539&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 4740 ₽'},
#  {'title': 'Hankook',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166951&h=150'],
#   'Width': '205',
#   'Height': '75',
#   'Diameter': '15',
#   'Cost': 'Цены от 6493 ₽'},
#  {'title': 'Kumho',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117930&h=150'],
#   'Width': '225',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 7553 ₽'},
#  {'title': 'R17 245/65 Hankook i*Pike RW11 107T (шип)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166936&h=150'],
#   'Width': '245',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 8942 ₽'},
#  {'title': '225/60R17 99H TL CrossContact LX Sport',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5096168&h=150'],
#   'Width': '225',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 11631 ₽'},
#  {'title': 'Blizzak VRX',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6085996&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 8599 ₽'},
#  {'title': 'R15 215/65 Hankook K424 Optimo ME02 96H (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166923&h=150'],
#   'Width': '215',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 5272 ₽'},
#  {'title': 'Шина Yokohama Geolandar I/T-S G073',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6046445&h=150'],
#   'Width': '225',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 7998 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086068&h=150'],
#   'Width': '185',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 5536 ₽'},
#  {'title': 'Шина Bridgestone BLIZZAK VRX 205/55R16',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6085959&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 8713 ₽'},
# ...
#   'Cost': 'Цены от 3510 ₽'},
#  {'title': 'Dunlop GRANDTREK SJ6 103Q',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041613&h=150'],
#   'Width': '245',
#   'Height': '55',
#   'Diameter': '19',
#   'Cost': 'Цены от 10098 ₽'},
#  {'title': '205/55R16 Dunlop SP TOURING T1 91H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164547&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 3902 ₽'},
#  {'title': 'R16 215/70 Hankook Dynapro HP RA23 100H (лето)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094391&h=150'],
#   'Width': '215',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 7621 ₽'},
#  {'title': 'R15 235/75 Hankook i*Pike RW11 105T (шип)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10166927&h=150'],
#   'Width': '235',
#   'Height': '75',
#   'Diameter': '15',
#   'Cost': 'Цены от 8568 ₽'},
#  {'title': '295/40ZR21 111Y TL XL FR ContiSportContact 5 SUV MO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6040602&h=150'],
#   'Width': '295',
#   'Height': '40',
#   'Diameter': '21',
#   'Cost': 'Цены от 22561 ₽'},
#  {'title': '205/55R16 91H P7cint(*)',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092870&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 5652 ₽'},
#  {'title': '205/60 R 15 95R Nordman RS XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117535&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 3974 ₽'},
#  {'title': 'Kumho',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5117917&h=150'],
#   'Width': '185',
#   'Height': '80',
#   'Diameter': '14',
#   'Cost': 'Цены от 5856 ₽'},
#  {'title': 'Michelin 285/60 R18 116H Latitude X-Ice 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6043638&h=150'],
#   'Width': '285',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 16230 ₽'},
#  {'title': '235/45ZR17 Dunlop SP SPORT LM704 94W',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095031&h=150'],
#   'Width': '235',
#   'Height': '45',
#   'Diameter': '17',
#   'Cost': 'Цены от 8436 ₽'},
#  {'title': 'Шина Tigar Sigura STUD 185/70R14',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6045596&h=150'],
#   'Width': '185',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 3143 ₽'},
#  {'title': '255/50R19 103W TL ML ContiSportContact 5 SUV SSR MO Extended',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6040595&h=150'],
#   'Width': '255',
#   'Height': '50',
#   'Diameter': '19',
#   'Cost': 'Цены от 17552 ₽'},
#  {'title': '235/60R18 103V S-Zero',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6089623&h=150'],
#   'Width': '235',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 13202 ₽'},
#  {'title': 'Шина Pirelli Winter ICE ZERO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10170334&h=150'],
#   'Width': '215',
#   'Height': '65',
#   'Diameter': '16',
#   'Cost': 'Цены от 5830 ₽'},
#  {'title': 'Шина Dunlop ICETOUCH D-STUD 225/50R17',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041737&h=150'],
#   'Width': '225',
#   'Height': '50',
#   'Diameter': '17',
#   'Cost': 'Цены от 9499 ₽'},
#  {'title': 'Шина Continental CONTICROSSCONTACT UHP 275/50R20',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6040646&h=150'],
#   'Width': '275',
#   'Height': '50',
#   'Diameter': '20',
#   'Cost': 'Цены от 27394 ₽'},
#  {'title': 'Nokian',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169552&h=150'],
#   'Width': '235',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 12906 ₽'},
#  {'title': 'Bridgestone',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092303&h=150'],
#   'Width': '255',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 14226 ₽'},
#  {'title': '245/70 R 16 111T Nokian Hakka SUV XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093017&h=150'],
#   'Width': '245',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 9002 ₽'},
#  {'title': '205/50 R 17 93W NOKIAN HAKKA BLACK XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092934&h=150'],
#   'Width': '205',
#   'Height': '50',
#   'Diameter': '17',
#   'Cost': 'Цены от 10608 ₽'},
#  {'title': 'Шина Pirelli WINTER SOTTOZERO Serie',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10170330&h=150'],
#   'Width': '235',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 13154 ₽'},
#  {'title': '235/50 ZR 18 101Y Nokian Hakka Black XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092927&h=150'],
#   'Width': '235',
#   'Height': '50',
#   'Diameter': '18',
#   'Cost': 'Цены от 12541 ₽'},
#  {'title': '245/45 ZR 17 99Y Nokian Hakka Black XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092922&h=150'],
#   'Width': '245',
#   'Height': '45',
#   'Diameter': '17',
#   'Cost': 'Цены от 11600 ₽'},
#  {'title': 'Michelin 91H Energy XM2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168423&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 6318 ₽'},
#  {'title': '215/70 R15C 109/107S AGILIS+',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168396&h=150'],
#   'Width': '215',
#   'Height': '70',
#   'Diameter': '15C',
#   'Cost': 'Цены от 9823 ₽'},
#  {'title': '225/40 ZR18 88Y PILOT SUPER SPORT ?',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168427&h=150'],
#   'Width': '225',
#   'Height': '40',
#   'Diameter': '18',
#   'Cost': 'Цены от 12822 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta 8 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044731&h=150'],
#   'Width': '245',
#   'Height': '55',
#   'Diameter': '19',
#   'Cost': 'Цены от 13458 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta 8 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044725&h=150'],
#   'Width': '265',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 14237 ₽'},
#  {'title': '225/45 R 17 94V NOKIAN HAKKA BLUE XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092999&h=150'],
#   'Width': '225',
#   'Height': '45',
#   'Diameter': '17',
#   'Cost': 'Цены от 8436 ₽'},
#  {'title': 'Pirelli',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6089867&h=150'],
#   'Width': '225',
#   'Height': '40',
#   'Diameter': '18',
#   'Cost': 'Цены от 10707 ₽'},
#  {'title': '245/40 ZR 18 97Y NOKIAN HAKKA BLACK XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092913&h=150'],
#   'Width': '245',
#   'Height': '40',
#   'Diameter': '18',
#   'Cost': 'Цены от 13608 ₽'},
#  {'title': 'Dunlop WINTER MAXX WM01 101T',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5118344&h=150'],
#   'Width': '225',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 8101 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta R2 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044439&h=150'],
#   'Width': '255',
#   'Height': '55',
#   'Diameter': '19',
#   'Cost': 'Цены от 12223 ₽'},
#  {'title': '205/60R16 92H TL ContiPremiumContact 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10163937&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 8489 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta R2 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044425&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 8842 ₽'},
#  {'title': '225/70R15C 112/110R (115N) TL VANCOWI 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5043091&h=150'],
#   'Width': '225',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 8688 ₽'},
#  {'title': 'Шина Dunlop Winter MAXX SJ8',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10164582&h=150'],
#   'Width': '245',
#   'Height': '55',
#   'Diameter': '19',
#   'Cost': 'Цены от 9810 ₽'},
#  {'title': '215/60R17 Dunlop GRANDTREK ST20 96H',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5094930&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 8904 ₽'},
#  {'title': '215/55 R 16 97H Nokian Hakka Green XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093073&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 7766 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta 8 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044715&h=150'],
#   'Width': '225',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 9548 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5091813&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '17',
#   'Cost': 'Цены от 11664 ₽'},
#  {'title': 'Continental',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5096827&h=150'],
#   'Width': '255',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 12756 ₽'},
#  {'title': 'LT285/75R16 Dunlop GRANDTREK AT3 122/119Q',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6041546&h=150'],
#   'Width': '285',
#   'Height': '75',
#   'Diameter': '16',
#   'Cost': 'Цены от 10226 ₽'},
#  {'title': '30X9.50R15LT Dunlop GRANDTREK AT3 104S',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5095076&h=150'],
#   'Width': '230',
#   'Height': '85',
#   'Diameter': '15',
#   'Cost': 'Цены от 7241 ₽'},
#  {'title': 'Pirelli',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6089862&h=150'],
#   'Width': '245',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 7397 ₽'},
#  {'title': 'Шина Nokian Hakkapeliitta 8 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044719&h=150'],
#   'Width': '265',
#   'Height': '65',
#   'Diameter': '17',
#   'Cost': 'Цены от 12029 ₽'},
#  {'title': '265/50 R 20 111R Nokian HKPL R2 SUV XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6044473&h=150'],
#   'Width': '265',
#   'Height': '50',
#   'Diameter': '20',
#   'Cost': 'Цены от 17544 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5091817&h=150'],
#   'Width': '245',
#   'Height': '55',
#   'Diameter': '19',
#   'Cost': 'Цены от 9507 ₽'},
#  {'title': '255/55R19 111V TL XL FR ContiSportContact 5 SUV',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5097791&h=150'],
#   'Width': '255',
#   'Height': '55',
#   'Diameter': '19',
#   'Cost': 'Цены от 15676 ₽'},
#  {'title': 'Michelin 205/60 R16 96H XL X-ICE 3',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6043757&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 7172 ₽'},
#  {'title': '215/50R17 95W TL XL FR ContiSportContact 5',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5097812&h=150'],
#   'Width': '215',
#   'Height': '50',
#   'Diameter': '17',
#   'Cost': 'Цены от 12395 ₽'},
#  {'title': '225/45 R 17 94W Nokian Hakka Blue XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093001&h=150'],
#   'Width': '225',
#   'Height': '45',
#   'Diameter': '17',
#   'Cost': 'Цены от 8862 ₽'},
#  {'title': 'Шина Pirelli Winter ICE ZERO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10170374&h=150'],
#   'Width': '235',
#   'Height': '55',
#   'Diameter': '19',
#   'Cost': 'Цены от 11886 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5091820&h=150'],
#   'Width': '185',
#   'Height': '65',
#   'Diameter': '15',
#   'Cost': 'Цены от 3362 ₽'},
#  {'title': 'Bridgestone',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5097926&h=150'],
#   'Width': '205',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 7018 ₽'},
#  {'title': 'Yokohama',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119890&h=150'],
#   'Width': '205',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 6030 ₽'},
#  {'title': 'Michelin 195/55 R16 91H XL X-ICE 3',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10168336&h=150'],
#   'Width': '195',
#   'Height': '55',
#   'Diameter': '16',
#   'Cost': 'Цены от 7373 ₽'},
#  {'title': '255/55 R18 109V XL LATITUDE TOUR HP N1',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093584&h=150'],
#   'Width': '255',
#   'Height': '55',
#   'Diameter': '18',
#   'Cost': 'Цены от 11074 ₽'},
#  {'title': '255/50R19 107V TL XL Contact UHP SSR',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6040649&h=150'],
#   'Width': '255',
#   'Height': '50',
#   'Diameter': '19',
#   'Cost': 'Цены от 18358 ₽'},
#  {'title': 'Blizzak Revo GZ',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6086067&h=150'],
#   'Width': '175',
#   'Height': '70',
#   'Diameter': '14',
#   'Cost': 'Цены от 4895 ₽'},
#  {'title': 'Шина Goodyear UltraGrip Ice Arctic',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6042095&h=150'],
#   'Width': '185',
#   'Height': '60',
#   'Diameter': '15',
#   'Cost': 'Цены от 4576 ₽'},
#  {'title': 'Good year 155/65R14 75T UltraGrip Ice Arctic D-STUD',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5071110&h=150'],
#   'Width': '155',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 4372 ₽'},
#  {'title': '265/70R16 112H TL FR MP82 CONQUERRA 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093787&h=150'],
#   'Width': '265',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 8777 ₽'},
#  {'title': '215/70R16 100H TL FR MP82 CONQUERRA 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10167527&h=150'],
#   'Width': '215',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 5825 ₽'},
#  {'title': 'Blizzak Spike-01',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6085938&h=150'],
#   'Width': '225',
#   'Height': '70',
#   'Diameter': '16',
#   'Cost': 'Цены от 10284 ₽'},
#  {'title': '235/60R18 107V G055',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5092418&h=150'],
#   'Width': '235',
#   'Height': '60',
#   'Diameter': '18',
#   'Cost': 'Цены от 9026 ₽'},
#  {'title': 'Barum',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5098300&h=150'],
#   'Width': '235',
#   'Height': '40',
#   'Diameter': '17',
#   'Cost': 'Цены от 7458 ₽'},
#  {'title': '205/70R15 96H TL FR MP82 CONQUERRA 2',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10167524&h=150'],
#   'Width': '205',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 5614 ₽'},
#  {'title': 'Pirelli',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6089936&h=150'],
#   'Width': '275',
#   'Height': '40',
#   'Diameter': '22',
#   'Cost': 'Цены от 28641 ₽'},
#  {'title': 'Barum',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5072367&h=150'],
#   'Width': '155',
#   'Height': '65',
#   'Diameter': '14',
#   'Cost': 'Цены от 3472 ₽'},
#  {'title': 'Шина Pirelli Winter ICE ZERO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6045343&h=150'],
#   'Width': '225',
#   'Height': '50',
#   'Diameter': '17',
#   'Cost': 'Цены от 10875 ₽'},
#  {'title': '235/75 R 15 109T NOKIAN ROTIIVA AT XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10169394&h=150'],
#   'Width': '235',
#   'Height': '75',
#   'Diameter': '15',
#   'Cost': 'Цены от 6356 ₽'},
#  {'title': 'Шина Pirelli Winter ICE ZERO',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6089903&h=150'],
#   'Width': '275',
#   'Height': '40',
#   'Diameter': '20',
#   'Cost': 'Цены от 14897 ₽'},
#  {'title': 'Шина Bridgestone BLIZZAK VRX 205/70R15',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=6039669&h=150'],
#   'Width': '205',
#   'Height': '70',
#   'Diameter': '15',
#   'Cost': 'Цены от 6743 ₽'},
#  {'title': '275/30 ZR19 (96Y) XL PILOT SUPER SPORT',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5093437&h=150'],
#   'Width': '275',
#   'Height': '30',
#   'Diameter': '19',
#   'Cost': 'Цены от 43300 ₽'},
#  {'title': '215/55 R 17 98V Nokian WR A3 XL',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=5119344&h=150'],
#   'Width': '215',
#   'Height': '55',
#   'Diameter': '17',
#   'Cost': 'Цены от 9726 ₽'},
#  {'title': '215/60R16 95V TL ContiEcoContact 5',
#   'link': ['https://www.emex.ru/Catalog/Catalog/GetImage?id=10163998&h=150'],
#   'Width': '215',
#   'Height': '60',
#   'Diameter': '16',
#   'Cost': 'Цены от 11936 ₽'}]

# %% [markdown]
# ### And last step, we need to save our dictionary to csv file row by row

# %%
with open('tires.csv', 'a+') as csvfile:
    fieldnames = ['title', 'link', 'Width', 'Height', 'Diameter', 'Cost']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    for row in rows:
        writer.writerow(row)

# %% [markdown]
# ### In the future we can automate this process by writing functions, however first of all we nee
